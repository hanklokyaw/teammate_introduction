# %%
# set varialbe for team member information
# using nested list
team_members=[
    [1, 
     'Htet Aung Kyaw', 
     'Hank',
     'He',
     'His',
     'him',
     'Myanmar(formerly Burma)', 
     'Asia',
     'Burmese, English, Chinese, and alittle Spanish',
     'International Economics and Trading', 
     'an International Business Manager and a UX Designer', 
     'Artificial Intellegence (A.I.) and Machine Learning (M.L.)',
     'Swimming, Table Tennis, or Board Games', 
     'California',
     'cool',
     'hkyaw@student.hult.edu'],
    [2, 
     'Kevin Kabore', 
     'Kevin',
     'He',
     'His',
     'him',
     'France', 
     'Europe',
     'French, English',
     'International Economics and Trading', 
     'an International Business Manager and a UX Designer', 
     'Artificial Intellegence (A.I.) and Machine Learning (M.L.)',
     'Swimming, Table Tennis, or Board Games', 
     'California',
     'awesome',
     'kkabore@student.hult.edu']
]

# prompt to ask the user's name as a variable
user_name = input(prompt="May I know your name: ")

# use input to take another input,
# in the same time print the welcome statement with user's name
# use int() because the input from user is string
# without converting to integer the if statement cannot match the case
selected_member = input(prompt=f"""
Hello {user_name}! A warm greeting from Team 2. 

Our team member are:
1. Htet Aung Kyaw
2. Kevin Kabore
3. Lynda Villarreal
4. Tangina Parvez
5. Udahayaa Tamilvanan

Which team mate that you would like to understand more?
(please enter member's name or number)
""")

# convert team members full name or nick name into team member id
# so it would be easier to use alias to display in the template
# use string instead of integer to match the user input format
print("before" + selected_member)
if selected_member == 'hank' or 'htet aung kyaw':
    selected_member = '1'
print("after" + selected_member)


# since the team member id are in string convert them into integer
if selected_member.isdigit() == True:
    selected_member = int(selected_member)
    # Add a little padding to format the output look more pleasent
    print("\n")

    #set alias for user's selected list index to inner list, to make the code more readible
    # selected_number -1 because python index state with 0
    member = team_members[selected_member - 1]

    # use if statement to check through the list of memberlist and print out template. 
    if selected_member == member[0]:
        print(f"Great! you chose our {member[-2]} team member {member[1]}."
              f" {member[4]} friends called {member[5]} {member[2]}.\n"
              f"{member[3]} is from a beautiful country called {member[6]}."
              f" Which is located in {member[7]}.\n"
              f"{member[2]} speaks {member[8]}.\n"
              f"{member[4]} undergraduate degree was {member[9]}.\n"
              f"{member[3]} has background as {member[10]}.\n\n"
              f"{member[2]} is currently persuing a master in Business Analytics at Hult International Business School.\n"
              f"{member[3]} is interested in {member[-5]}.\n"
              f"{member[2]} probably will look for an analytics career at {member[-3]} region after graduation.\n"
              f"{member[2]} spends time enjoying {member[4].lower()} hobbies. If you like {member[-4]}\n"
              f"drop {member[5]} an email at {member[-1]}. {member[3]} would be more than happy to connnect with you."
             )
    else:
        print(f"Sorry {user_name}! we don't have that team member. Goodbye.")

else:
    print(f"Sorry {user_name}! we don't have that team member. Goodbye.")
# Out:
# May I know your name: l
#
# Hello l! A warm greeting from Team 2.
#
# Our team member are:
# 1. Htet Aung Kyaw
# 2. Kevin Kabore
# 3. Lynda Villarreal
# 4. Tangina Parvez
# 5. Udahayaa Tamilvanan
#
# Which team mate that you would like to understand more?
# (please enter member's name or number)
# 2
# before2
# after1
#
#
# Great! you chose our cool team member Htet Aung Kyaw. His friends called him Hank.
# He is from a beautiful country called Myanmar(formerly Burma). Which is located in Asia.
# Hank speaks Burmese, English, Chinese, and alittle Spanish.
# His undergraduate degree was International Economics and Trading.
# He has background as an International Business Manager and a UX Designer.
#
# Hank is currently persuing a master in Business Analytics at Hult International Business School.
# He is interested in Artificial Intellegence (A.I.) and Machine Learning (M.L.).
# Hank probably will look for an analytics career at California region after graduation.
# ...
